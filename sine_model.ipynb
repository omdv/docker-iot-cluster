# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from math import pi
from datetime import datetime

# %%
tt = datetime.now().timestamp()
times = np.arange(0, 3600)
# Out:
# 1543089461.646336

# %%
A = 10
B = 6.28/(60 * 5)
C = 
D = 0
params = [A, B, C, D]
ys = params[0] * np.sin(params[1] * (times + params[2])) + params[3]
plt.plot(times, ys)
plt.xlim(0, 3600)
# Out:
# (0, 3600)

# %%
random.random()
# Out:
# 0.06407446893984514
